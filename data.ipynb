# %%
import pandas as pd

# %%
dff=pd.read_csv('exercise_dataset.csv')
dff
# Out:
#         ID     Exercise       Calories Burn       Dream Weight  \
# 0        1   Exercise 2         286.9598505        91.89253067
# 1        2   Exercise 7         343.4530361        64.16509681
# 2        3   Exercise 4         261.2234649        70.84622352
# 3        4   Exercise 5         127.1838584        79.47700756
# 4        5  Exercise 10         416.3183735        89.96022608
# ...    ...          ...                 ...                ...
# 6555  6450   Exercise 4  261.10470064839626  92.53265155833654
# 6556  6451  Exercise 10  238.75593125946457  91.86637940980307
# 6557  6452  Exercise 10  201.35357634394668  97.14505505159714
# 6558  6453   Exercise 5  200.69974443411724  93.46434930605588
# 6559  6454   Exercise 2  203.45320451170048  83.67580400171121
#
#           Actual Weight   Age  Gender Duration Heart Rate                 BMI  \
# 0           96.30111546    45    Male       37        170         29.42627467
# 1            61.1046681    25    Male       43        142         21.28634599
# 2           71.76672384    20    Male       20        148          27.8995916
# 3           82.98445557    33    Male       39        170         33.72955245
# 4           85.64317443    29  Female       34        118         23.28611341
# ...                 ...   ...     ...      ...        ...                 ...
# 6555  75.07431787498139  37.0    Male     18.0      142.0   58.21298673868801
# 6556   79.3022659035273  39.0  Female     51.0      141.0   57.34875813488217
# 6557  80.41948431043107  34.0  Female     20.0      146.0  42.209017930816806
# 6558  71.09308873103583  23.0    Male     20.0      189.0   32.79409983874228
# 6559  70.59179722355367  35.0    Male     26.0        NaN  63.319255310948535
#
#      Weather Conditions Exercise Intensity
# 0                 Rainy                  5
# 1                 Rainy                  5
# 2                Cloudy                  4
# 3                 Sunny                 10
# 4                Cloudy                  3
# ...                 ...                ...
# 6555             Cloudy                9.0
# 6556              Sunny                NaN
# 6557             Cloudy                NaN
# 6558              Sunny                1.0
# 6559             Cloudy                5.0
#
# [6560 rows x 12 columns]

# %%
# A function to check for missing values in our dataset
def check_missing_values(data):
    # Count missing values in each column
    missing_values = data.isnull().sum()

    # Convert missing values count to percentage of total rows
    missing_percent = (missing_values / len(data)) * 100

    # Combine the missing values count and percent into a DataFrame
    missing_df = pd.concat([missing_values, missing_percent], axis=1)
    missing_df.columns = ['Missing Values', '% of Total']

    # Return only columns with missing values
    missing_df = missing_df[missing_df['Missing Values'] > 0]

    return missing_df

# Check missing values in each dataset
display(check_missing_values(dff))
# Out:
#                     Missing Values  % of Total
# Calories Burn                  201    3.064024
# Dream Weight                   205    3.125000
# Actual Weight                  173    2.637195
# Age                            187    2.850610
# Gender                         214    3.262195
# Duration                       186    2.835366
# Heart Rate                     202    3.079268
# BMI                            191    2.911585
# Weather Conditions             195    2.972561
# Exercise Intensity             223    3.399390

# %%
dff.describe()
# Out:
#           ID     Exercise Calories Burn Dream Weight Actual Weight   Age  \
# count   6560         6560          6359         6355          6387  6373
# unique  6454           11          6349         6346          6378    86
# top     4503  Exercise 10   185.9518698  87.44282248   80.77618934    45
# freq       2          709             2            2             2   134
#
#         Gender Duration Heart Rate          BMI Weather Conditions  \
# count     6346     6374       6358         6369               6365
# unique       4       86        134         6359                  5
# top     Female       43        156  32.44776394             Cloudy
# freq      3219      132        102            2               2260
#
#        Exercise Intensity
# count                6337
# unique                 21
# top                     4
# freq                  518

# %%
# A function to check for duplicates in our datasets
def check_duplicates(df):
    """
    This function checks for and returns any duplicates in a given dataframe.
    """
    duplicates = df[df.duplicated()]
    if duplicates.shape[0] == 0:
        print("No duplicates found in the dataset")
    else:
        print("Duplicates found in the dataset:")
        return duplicates
# Calling for the function to check for duplicates
check_duplicates(dff)
# Out:
# Duplicates found in the dataset:
#         ID     Exercise Calories Burn Dream Weight Actual Weight Age  Gender  \
# 3864  3859  Exercise 10   144.3056992  87.44282248    89.5469276  36    Male
# 3865  3860   Exercise 5   154.1131439  98.14729067   96.74513279  20  Female
# 3866  3861   Exercise 4   486.3927685  97.59895722   92.70057328  21  Female
# 3867  3862   Exercise 4   264.3077311  94.94661237   96.77893592  57    Male
# 3869  3864   Exercise 7   116.3604168  56.75742433   59.83340349  35    Male
#
#      Duration Heart Rate          BMI Weather Conditions Exercise Intensity
# 3864       55        178  33.38330541             Cloudy                  1
# 3865       22        139  32.44776394             Cloudy                  7
# 3866       49        160  26.60247496              Rainy                  5
# 3867       56        167  31.43534822              Rainy                  9
# 3869       22        134  29.58133002              Rainy                  1

# %%
dff.drop_duplicates(inplace=True)

# %%
check_duplicates(dff)
# Out:
# No duplicates found in the dataset

# %%
dff
# Out:
#         ID     Exercise       Calories Burn       Dream Weight  \
# 0        1   Exercise 2         286.9598505        91.89253067
# 1        2   Exercise 7         343.4530361        64.16509681
# 2        3   Exercise 4         261.2234649        70.84622352
# 3        4   Exercise 5         127.1838584        79.47700756
# 4        5  Exercise 10         416.3183735        89.96022608
# ...    ...          ...                 ...                ...
# 6555  6450   Exercise 4  261.10470064839626  92.53265155833654
# 6556  6451  Exercise 10  238.75593125946457  91.86637940980307
# 6557  6452  Exercise 10  201.35357634394668  97.14505505159714
# 6558  6453   Exercise 5  200.69974443411724  93.46434930605588
# 6559  6454   Exercise 2  203.45320451170048  83.67580400171121
#
#           Actual Weight   Age  Gender Duration Heart Rate                 BMI  \
# 0           96.30111546    45    Male       37        170         29.42627467
# 1            61.1046681    25    Male       43        142         21.28634599
# 2           71.76672384    20    Male       20        148          27.8995916
# 3           82.98445557    33    Male       39        170         33.72955245
# 4           85.64317443    29  Female       34        118         23.28611341
# ...                 ...   ...     ...      ...        ...                 ...
# 6555  75.07431787498139  37.0    Male     18.0      142.0   58.21298673868801
# 6556   79.3022659035273  39.0  Female     51.0      141.0   57.34875813488217
# 6557  80.41948431043107  34.0  Female     20.0      146.0  42.209017930816806
# 6558  71.09308873103583  23.0    Male     20.0      189.0   32.79409983874228
# 6559  70.59179722355367  35.0    Male     26.0        NaN  63.319255310948535
#
#      Weather Conditions Exercise Intensity
# 0                 Rainy                  5
# 1                 Rainy                  5
# 2                Cloudy                  4
# 3                 Sunny                 10
# 4                Cloudy                  3
# ...                 ...                ...
# 6555             Cloudy                9.0
# 6556              Sunny                NaN
# 6557             Cloudy                NaN
# 6558              Sunny                1.0
# 6559             Cloudy                5.0
#
# [6555 rows x 12 columns]

# %%
data=pd.read_csv('reviews_1000_1500.csv')
data
# Out:
# C:\Users\iantu\AppData\Local\Temp\ipykernel_2680\2365619515.py:1: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   data=pd.read_csv('reviews_1000_1500.csv')
#         Unnamed: 0    author_id  rating  is_recommended  helpfulness  \
# 0                0   8554483509       2             0.0          NaN
# 1                1  24710523057       2             0.0     1.000000
# 2                2   8429283179       5             1.0     0.941176
# 3                3   8105185455       1             0.0     0.000000
# 4                4   1515931062       1             0.0     0.000000
# ...            ...          ...     ...             ...          ...
# 119312      119312   9109189891       5             1.0          NaN
# 119313      119313   8115925555       5             1.0          NaN
# 119314      119314  10723607564       5             1.0          NaN
# 119315      119315   5953458355       5             1.0          NaN
# 119316      119316  24486949963       5             1.0          NaN
#
#         total_feedback_count  total_neg_feedback_count  \
# 0                          0                         0
# 1                          2                         0
# 2                         34                         2
# 3                          5                         5
# 4                          7                         7
# ...                      ...                       ...
# 119312                     0                         0
# 119313                     0                         0
# 119314                     0                         0
# 119315                     0                         0
# 119316                     0                         0
#
#         total_pos_feedback_count submission_time  \
# 0                              0      2023-03-21
# 1                              2      2023-03-07
# 2                             32      2023-03-01
# 3                              0      2023-02-27
# 4                              0      2023-02-27
# ...                          ...             ...
# 119312                         0      2022-04-29
# 119313                         0      2022-04-29
# 119314                         0      2022-04-29
# 119315                         0      2022-04-29
# 119316                         0      2022-04-29
#
#                                               review_text  \
# 0       This was gifted by Supergoop! in exchange for ...
# 1       I didn’t like it; too much product comes out w...
# 2       Y’all….I’m begging for everyone to read instru...
# 3       I have not figured out how to use this product...
# 4       I’m at a loss as to how to use this thing!!! C...
# ...                                                   ...
# 119312  I LOVE this stuff! It works amazingly well at ...
# 119313  love this micellar water from Milk! it removes...
# 119314  I loveeeeee Milk!!! Just discovered this brand...
# 119315  My new favorite makeup remover. First of all, ...
# 119316  First of all, this actually removed ALL of my ...
#
#                               review_title  skin_tone eye_color    skin_type  \
# 0       Nice packaging but easy to overuse      light     brown  combination
# 1                Packaging is not suits le        NaN     brown  combination
# 2                        PLS READ THIS LOL      light     green       normal
# 3                                At a loss        tan     brown  combination
# 4                             NOT for me!!       fair      blue  combination
# ...                                    ...        ...       ...          ...
# 119312                      Great product!        NaN       NaN          NaN
# 119313                                 NaN     medium     brown         oily
# 119314                                 NaN  mediumTan     brown          dry
# 119315                Works extremely well      light      blue  combination
# 119316             Cleansing & Hydrating!!       fair      blue  combination
#
#        hair_color product_id  \
# 0             NaN    P467976
# 1             NaN    P467976
# 2           brown    P467976
# 3           black    P467976
# 4          blonde    P467976
# ...           ...        ...
# 119312        NaN    P500101
# 119313        red    P500101
# 119314      black    P500101
# 119315     blonde    P500101
# 119316        red    P500101
#
#                                              product_name   brand_name  \
# 0       (Re)setting 100% Mineral Powder Sunscreen SPF ...   Supergoop!
# 1       (Re)setting 100% Mineral Powder Sunscreen SPF ...   Supergoop!
# 2       (Re)setting 100% Mineral Powder Sunscreen SPF ...   Supergoop!
# 3       (Re)setting 100% Mineral Powder Sunscreen SPF ...   Supergoop!
# 4       (Re)setting 100% Mineral Powder Sunscreen SPF ...   Supergoop!
# ...                                                   ...          ...
# 119312      Hydro Ungrip Makeup Remover + Cleansing Water  MILK MAKEUP
# 119313      Hydro Ungrip Makeup Remover + Cleansing Water  MILK MAKEUP
# 119314      Hydro Ungrip Makeup Remover + Cleansing Water  MILK MAKEUP
# 119315      Hydro Ungrip Makeup Remover + Cleansing Water  MILK MAKEUP
# 119316      Hydro Ungrip Makeup Remover + Cleansing Water  MILK MAKEUP
#
#         price_usd
# 0            35.0
# 1            35.0
# 2            35.0
# 3            35.0
# 4            35.0
# ...           ...
# 119312       32.0
# 119313       32.0
# 119314       32.0
# 119315       32.0
# 119316       32.0
#
# [119317 rows x 19 columns]

# %%
display(check_missing_values(data))
# Out:
#                 Missing Values  % of Total
# is_recommended            8896    7.455769
# helpfulness              52007   43.587251
# review_text                 89    0.074591
# review_title             35556   29.799609
# skin_tone                15248   12.779403
# eye_color                14663   12.289112
# skin_type                 7605    6.373777
# hair_color               20557   17.228894

# %%
data2=pd.read_csv('Crop_recommendation.csv')
data2
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536    rice
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537    rice
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248    rice
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034    rice
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340    rice
# ...   ...  ..  ..          ...        ...       ...         ...     ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee
#
# [2200 rows x 8 columns]

# %%
display(check_missing_values(data2))
# Out:
# Empty DataFrame
# Columns: [Missing Values, % of Total]
# Index: []
